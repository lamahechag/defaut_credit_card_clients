# %%
from skfda import FDataGrid
import numpy as np
import pandas as pd
import numpy as np
import sklearn
# import jtplot submodule from jupyterthemes
from jupyterthemes import jtplot
# currently installed theme will be used to
# set plot style if no arguments provided
jtplot.style()

# %%
df = pd.read_excel("default of credit card clients.xls", header=1)
# put ID as DataFrame INDEX
df.set_index('ID', inplace=True)

# %%
aux = df[['BILL_AMT6', 'BILL_AMT5', 'BILL_AMT4', 'BILL_AMT3', 'BILL_AMT2', 'BILL_AMT1']].values

# %%
fd = FDataGrid(aux, [1,2,3,4,5,6],
               dataset_name='repayment',
               argument_names=['t'],
               coordinate_names=['x(t)'])

# %%
fd[:1000].plot(group=df['default payment next month'].values,
               group_colors=['red', 'blue'])

# %%
from skfda.exploratory.visualization import Boxplot

fdBoxplot = Boxplot(fd)
fdBoxplot.show_full_outliers = False
fdBoxplot.plot()
